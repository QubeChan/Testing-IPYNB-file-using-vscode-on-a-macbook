# %% [markdown]
# # Testing Google Colab with VSCode using python and markdown
# - This is all new to me and it seems cool and useful to work on this offline instead of having to be connected online to run a a notebook document used by Jupyter Notebook and I can use Python language on here while also using markdown laguage which I'm learning!

# %%
# Testing String Interpolation with print newly added f-strings
# Method called literal string interpolation
print(f'I have {3} books on my desk')
# Out:
# I have 3 books on my desk
